# %%
pip install requests

# %%
import requests
import json
from PIL import Image
import urllib.request
import matplotlib.pyplot as plt

# %%
url = "https://modelslab.com/api/v6/realtime/text2img"
api_key = "XXXXXXXXXXX"

# %%
# Headers de la petición
headers = {
  'Content-Type': 'application/json'
}

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a woman with hippie style, looking at the camera",
    "negative_prompt": "bad quality",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "ultra realistic portrait of a samurai in the middle of the streets of the modern city of Tokyo",
    "negative_prompt": "bad quality",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a woman walking through the streets of mexico on the day of the dead, the woman is wearing a hat and her face painted as catrina",
    "negative_prompt": "bad quality",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a cat in an elegant suit playing the piano",
    "negative_prompt": "bad quality",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)
data = response.json()

# %%
print(data)
# Out:
# {'status': 'processing', 'tip': 'Your image is processing in background, you can get this image using fetch API', 'eta': 19.54, 'message': 'Try to fetch request after seconds estimated', 'fetch_result': 'https://modelslab.com/api/v6/realtime/fetch/114775746', 'id': 114775746, 'output': [], 'meta': {'base64': 'no', 'enhance_prompt': 'no', 'enhance_style': None, 'file_prefix': '7c7a60f6-da9d-41fb-b205-fd8281bac349', 'guidance_scale': 0, 'height': 512, 'instant_response': 'no', 'n_samples': 1, 'negative_prompt': 'bad quality', 'opacity': 0.7, 'outdir': 'out', 'padding_down': 10, 'padding_right': 10, 'pag_scale': 0.1, 'prompt': 'a cat in an elegant suit playing the piano', 'rescale': 'yes', 'safety_checker': 'no', 'safety_checker_type': 'black', 'scale_down': 6, 'seed': 2138411181, 'temp': 'no', 'watermark': 'yes', 'width': 512}, 'future_links': ['https://pub-3626123a908346a7a8be8d9295f44e26.r2.dev/generations/7c7a60f6-da9d-41fb-b205-fd8281bac349-0.png']}

# %%
url_fetch = "https://modelslab.com/api/v6/realtime/fetch/114775746"

# %%
payload = json.dumps({
 "key": api_key
})

# %%
# Ejecutar petición
response = requests.post(url_fetch, data=payload, headers=headers)
data = response.json()

# %%
print(data)
# Out:
# {'status': 'success', 'id': 114775746, 'output': ['https://pub-3626123a908346a7a8be8d9295f44e26.r2.dev/generations/7c7a60f6-da9d-41fb-b205-fd8281bac349-0.png'], 'proxy_links': ['https://cdn2.stablediffusionapi.com/generations/7c7a60f6-da9d-41fb-b205-fd8281bac349-0.png']}

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "an astronaut in an elegant suit playing the piano, on the moon",
    "negative_prompt": "bad quality",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a woman in an elegant dress and a masquerade mask, on the rooftops of paris hyperrealistic, full body, detailed clothing, highly detailed, cinematic lighting, stunningly beautiful, intricate, sharp focus, f/1. 8, 85mm, (centered image composition), (professionally color graded), ((bright soft diffused light)), volumetric fog, trending on instagram, trending on tumblr",
    "negative_prompt": "(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy",
    "model_id": "flux",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)

# %%
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "creates a captivating portrait of a voluptuous bohemian woman with green eyes and long, wavy red hair, she is standing. his expression is contemplative, reflecting a moment of deep reflection. she wears a long white dress, with bare shoulders and a deep neck, complemented by a necklace and various bohemian jewelry that accentuates her bohemian style. portrait photography hyperrealistic, full body, detailed clothing, highly detailed, cinematic lighting, stunningly beautiful, intricate, sharp focus, f/1. 8, 85mm, (centered image composition), (professionally color graded), ((bright soft diffused light)), volumetric fog, trending on instagram, trending on tumblr",
    "negative_prompt": "(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy",
    "model_id": "flux",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)

# %%
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a medieval knight, fighting a dragon, photography hyperrealistic, full body, detailed clothing, highly detailed, cinematic lighting, stunningly beautiful, intricate, sharp focus, f/1. 8, 85mm, (centered image composition), (professionally color graded), ((bright soft diffused light)), volumetric fog, trending on instagram, trending on tumblr",
    "negative_prompt": "(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy",
    "model_id": "flux",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)

# %%
data = response.json()

# %%
print(data)
# Out:
# {'status': 'processing', 'tip': 'Your image is processing in background, you can get this image using fetch API', 'eta': 29.37, 'message': 'Try to fetch request after seconds estimated', 'fetch_result': 'https://modelslab.com/api/v6/realtime/fetch/114849102', 'id': 114849102, 'output': [], 'meta': {'base64': 'no', 'enhance_prompt': 'no', 'enhance_style': None, 'file_prefix': 'c07bae3c-1aef-4124-b95c-7d9ee9176859', 'guidance_scale': 0, 'height': 512, 'instant_response': 'no', 'n_samples': 1, 'negative_prompt': '(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy', 'opacity': 0.7, 'outdir': 'out', 'padding_down': 10, 'padding_right': 10, 'pag_scale': 0.1, 'prompt': 'a m
# ...

# %%
url_fetch = "https://modelslab.com/api/v6/realtime/fetch/114849102"

# %%
payload = json.dumps({
 "key": api_key
})

# %%
# Ejecutar petición
response = requests.post(url_fetch, data=payload, headers=headers)
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a woman sitting in the shade of a tree, while reading a book hyperrealistic, full body, detailed clothing, highly detailed, cinematic lighting, stunningly beautiful, intricate, sharp focus, f/1. 8, 85mm, (centered image composition), (professionally color graded), ((bright soft diffused light)), volumetric fog, trending on instagram, trending on tumblr",
    "negative_prompt": "(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy",
    "model_id": "flux",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None,
    "guidance": 7.5,
    "upscale": None,
    "clip_skip": "2",
    "free_u": None,
    "instant_response": None,
    "steps": 30,
    "use_karras_sigmas": "yes",
    "algorithm_type": None,
    "safety_checker_type": None,
    "tomesd": True
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)

# %%
data = response.json()

# %%
print(data)
# Out:
# {'status': 'processing', 'tip': 'Your image is processing in background, you can get this image using fetch API', 'eta': 11.24, 'message': 'Try to fetch request after seconds estimated', 'fetch_result': 'https://modelslab.com/api/v6/realtime/fetch/114850958', 'id': 114850958, 'output': [], 'meta': {'base64': 'no', 'enhance_prompt': 'no', 'enhance_style': None, 'file_prefix': 'd83a054f-b682-4c5f-937f-9df3d0166b98', 'guidance_scale': 0, 'height': 512, 'instant_response': 'no', 'n_samples': 1, 'negative_prompt': '(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy', 'opacity': 0.7, 'outdir': 'out', 'padding_down': 10, 'padding_right': 10, 'pag_scale': 0.1, 'prompt': 'a w
# ...

# %%
url_fetch = "https://modelslab.com/api/v6/realtime/fetch/114850958"

# %%
payload = json.dumps({
 "key": api_key
})

# %%
# Ejecutar petición
response = requests.post(url_fetch, data=payload, headers=headers)
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Body de la petición
payload = json.dumps({
    "key" : api_key,
    "prompt": "a wedding couple hugging and about to kiss, she is a circus performer in gypsy clothing, he is a businessman in an elegant suit hyperrealistic, full body, detailed clothing, highly detailed, cinematic lighting, stunningly beautiful, intricate, sharp focus, f/1. 8, 85mm, (centered image composition), (professionally color graded), ((bright soft diffused light)), volumetric fog, trending on instagram, trending on tumblr",
    "negative_prompt": "(child:1.5), ((((underage)))), ((((child)))), (((kid))), (((preteen))), (teen:1.5) ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, extra limbs, disfigured, deformed, body out of frame, bad anatomy, watermark, signature, cut off, low contrast, underexposed, overexposed, bad art, beginner, amateur, distorted face, blurry, draft, grainy",
    "model_id": "flux",
    "width": "512",
    "height": "512",
    "safety_checker": False,
    "seed": None,
    "samples":1,
    "base64":False,
    "webhook": None,
    "track_id": None,
    "guidance": 7.5,
    "upscale": None,
    "clip_skip": "2",
    "free_u": None,
    "instant_response": None,
    "steps": 30,
    "use_karras_sigmas": "yes",
    "algorithm_type": None,
    "safety_checker_type": None,
    "tomesd": True
})

# %%
# Ejecutar petición
response = requests.post(url, data=payload, headers=headers)

# %%
data = response.json()

# %%
# Mostrar imágenes generadas
for image in data['output']:
    img = Image.open(requests.get(image, stream=True).raw)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
